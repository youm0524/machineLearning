# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("1.csv")
df
# Out:
#      QuestionId  Feature1_SelectionEntropy  Feature2_CorrectnessEntropy  \
# 0             0                        484                          247
# 1             1                        844                          293
# 2             2                        124                          481
# 3             3                        908                          915
# 4             4                        150                          405
# ..          ...                        ...                          ...
# 943         943                        780                          274
# 944         944                        188                          938
# 945         945                        331                          324
# 946         946                        397                          178
# 947         947                        643                          489
#
#      Feature3_Difficulty  Feature1+2  All
# 0                    458         391  434
# ...

# %%
test = pd.read_csv('quality_response_remapped_public.csv')
test
# Out:
#     Unnamed: 0.1  Unnamed: 0  left  right  T1_ALR  T2_CL  T3_GF  T4_MQ  T5_NS
# 0              0           0   909    318       2      2      2    1.0      2
# 1             16          16   285    609       2      2      2    2.0      2
# 2             48          48   132    271       1      2      2    2.0      1
# 3             38          38   704    127       2      2      1    2.0      2
# 4             33          33    16    586       1      1      2    2.0      2
# 5             17          17    56    865       2      1      2    2.0      2
# 6             27          27   233    478       1      1      1    1.0      2
# 7             41          41   877    620       2      2      2    2.0      2
# 8              5           5   246    733       1      1      1    2.0      1
# 9             35          35   668    741       1      1      1    1.0      1
# 10            11          11   691      4       2      2      2    1.0      1
# ...

# %%
df = df.drop(['Feature1_SelectionEntropy', 'Feature2_CorrectnessEntropy', 'Feature3_Difficulty', 'Feature1+2'], axis = 1)
df
# Out:
#      QuestionId  All
# 0             0  434
# 1             1  661
# 2             2   76
# 3             3  924
# 4             4   12
# ..          ...  ...
# 943         943  656
# 944         944  448
# 945         945  215
# 946         946  235
# 947         947  635
#
# [948 rows x 2 columns]

# %%
test_left = test['left']
test_right = test['right']
test_left
# Out:
# 0     909
# 1     285
# 2     132
# 3     704
# 4      16
# 5      56
# 6     233
# 7     877
# 8     246
# 9     668
# 10    691
# 11    403
# 12    404
# 13    202
# 14    555
# 15    527
# 16    225
# 17    316
# 18    363
# 19    118
# 20    676
# 21    527
# 22    327
# 23    158
# 24    547
# Name: left, dtype: int64

# %%
x = df.iloc[test_left[0],1]
y = df.iloc[test_right[0], 1]
x < y
# Out:
# False

# %%
count = 0
for x in test.iterrows() :
    l = df.iloc[test_left[x[0]],1]
    r = df.iloc[test_right[x[0]],1]
    count += 1
    if l < r :
        test['ans'][x[0]] = 1
    else :
        test['ans'][x[0]] = 2
    
test
# Out:
# /var/folders/51/t3gqpmhd0ws50sv5mmn33j0m0000gn/T/ipykernel_38319/2477757381.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ans'][x[0]] = 2
# /var/folders/51/t3gqpmhd0ws50sv5mmn33j0m0000gn/T/ipykernel_38319/2477757381.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ans'][x[0]] = 1
#     Unnamed: 0.1  Unnamed: 0  left  right  T1_ALR  T2_CL  T3_GF  T4_MQ  T5_NS  \
# 0              0           0   909    318       2      2      2    1.0      2
# 1             16          16   285    609       2      2      2    2.0      2
# ...

# %%
t1 = 0
t2 = 0
t3 = 0
t4 = 0
t5 = 0
for x in test.iterrows():
    if test['T1_ALR'][x[0]] == test['ans'][x[0]]:
        t1 += 1
    if test['T2_CL'][x[0]] == test['ans'][x[0]]:
        t2 += 1
    if test['T3_GF'][x[0]] == test['ans'][x[0]]:
        t3 += 1
    if test['T4_MQ'][x[0]] == test['ans'][x[0]]:
        t4 += 1
    if test['T5_NS'][x[0]] == test['ans'][x[0]]:
        t5 += 1
        
print("validation")
print("T1 = ", t1/count * 100, "T2 = ", t2/count * 100, "T3 = ", t3/count*100, "T4 = ", t4/count*100, "T5 = ", t5/count*100)
# Out:
# validation
# T1 =  72.0 T2 =  76.0 T3 =  84.0 T4 =  64.0 T5 =  72.0

# %%
test_private = pd.read_csv('quality_response_remapped_private.csv')
test_private
# Out:
#     Unnamed: 0.1  Unnamed: 0  left  right  T1_ALR  T2_CL  T3_GF  T4_MQ  T5_NS
# 0             15          15   145    762       2      2      2    2.0      2
# 1             31          31   307    208       1      1      1    2.0      1
# 2             25          25   278    195       1      1      1    1.0      1
# 3              3           3    13    153       2      2      2    2.0      2
# 4             40          40    23    100       2      1      1    1.0      1
# 5             23          23   532    104       1      1      2    2.0      1
# 6             21          21   155    479       1      1      1    1.0      2
# 7              1           1   304    907       1      1      1    1.0      1
# 8             26          26   242    129       1      1      1    1.0      1
# 9             39          39   688    287       2      1      2    2.0      2
# 10             7           7   289     72       2      2      1    2.0      2
# ...

# %%
test_private_left = test_private['left']
test_private_right = test_private['right']
test_private_left
# Out:
# 0     145
# 1     307
# 2     278
# 3      13
# 4      23
# 5     532
# 6     155
# 7     304
# 8     242
# 9     688
# 10    289
# 11     40
# 12    184
# 13    439
# 14    394
# 15    744
# 16    432
# 17    611
# 18    376
# 19    515
# 20    570
# 21    361
# 22    365
# 23    740
# 24    798
# Name: left, dtype: int64

# %%
test_private['ans'] = 0
count2 = 0
for x in test.iterrows() :
    l = df.iloc[test_private_left[x[0]],1]
    r = df.iloc[test_private_right[x[0]],1]
    count2 += 1
    if l < r :
        test_private['ans'][x[0]] = 1
    else :
        test_private['ans'][x[0]] = 2
    
test_private
# Out:
# /var/folders/51/t3gqpmhd0ws50sv5mmn33j0m0000gn/T/ipykernel_38319/3177966737.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_private['ans'][x[0]] = 2
# /var/folders/51/t3gqpmhd0ws50sv5mmn33j0m0000gn/T/ipykernel_38319/3177966737.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_private['ans'][x[0]] = 1
#     Unnamed: 0.1  Unnamed: 0  left  right  T1_ALR  T2_CL  T3_GF  T4_MQ  T5_NS  \
# 0             15          15   145    762       2      2      2    2.0      2
# 1             31          31   307    208       1      1      1    2.0      1
# ...

# %%
t3_private = 0
for x in test.iterrows():
    if test['T3_GF'][x[0]] == test['ans'][x[0]]:
        t3_private += 1
        
print("validation")
print("T3 = ", t3_private/count2*100)
# Out:
# validation
# T3 =  84.0
